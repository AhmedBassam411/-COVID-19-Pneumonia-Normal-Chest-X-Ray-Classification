# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# ---------------- CONFIG ----------------
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 40
DATA_DIR = "Data"  # make sure it contains 'train' and 'test' subfolders
MODEL_PATH = "cnn_model.keras"

CLASS_NAMES = ["COVID19", "NORMAL", "PNEUMONIA"]

# ---------------- DATA PREP ----------------
# Training generator with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    os.path.join(DATA_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training",
    shuffle=True
)

val_generator = train_datagen.flow_from_directory(
    os.path.join(DATA_DIR, "train"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation",
    shuffle=False
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    os.path.join(DATA_DIR, "test"),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

# ---------------- CLASS WEIGHTS ----------------
from sklearn.utils import class_weight

y_train = train_generator.classes
class_weights_values = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = {i: cw for i, cw in enumerate(class_weights_values)}

# ---------------- CNN MODEL ----------------
def build_cnn():
    inputs = tf.keras.Input(shape=(224, 224, 3))

    x = tf.keras.layers.Conv2D(32, 3, padding="same", activation="relu")(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(64, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(128, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D()(x)

    x = tf.keras.layers.Conv2D(256, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.Dropout(0.5)(x)

    outputs = tf.keras.layers.Dense(len(CLASS_NAMES), activation="softmax")(x)
    return tf.keras.Model(inputs, outputs)

model = build_cnn()
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=["accuracy"]
)

model.summary()

# ---------------- CALLBACKS ----------------
callbacks = [
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    ModelCheckpoint(MODEL_PATH, monitor="val_accuracy", save_best_only=True, verbose=1)
]

# ---------------- TRAINING ----------------
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    class_weight=class_weights,
    callbacks=callbacks
)
# Out:
# c:\Users\msi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Found 4116 images belonging to 3 classes.
# Found 1028 images belonging to 3 classes.
# Found 1288 images belonging to 3 classes.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 456,899 (1.74 MB)
#  Trainable params: 455,939 (1.74 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5582 - loss: 0.8929
# Epoch 1: val_accuracy improved from None to 0.42023, saving model to cnn_model.keras
#
# Epoch 1: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 356s 3s/step - accuracy: 0.6681 - loss: 0.7440 - val_accuracy: 0.4202 - val_loss: 1.6257 - learning_rate: 1.0000e-04
# Epoch 2/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7767 - loss: 0.5795
# Epoch 2: val_accuracy did not improve from 0.42023
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.7937 - loss: 0.5433 - val_accuracy: 0.1158 - val_loss: 2.6360 - learning_rate: 1.0000e-04
# Epoch 3/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8267 - loss: 0.4869
# Epoch 3: val_accuracy did not improve from 0.42023
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.8294 - loss: 0.4727 - val_accuracy: 0.0944 - val_loss: 3.4393 - learning_rate: 1.0000e-04
# Epoch 4/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8495 - loss: 0.4538
# Epoch 4: val_accuracy did not improve from 0.42023
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.8513 - loss: 0.4442 - val_accuracy: 0.1333 - val_loss: 2.9459 - learning_rate: 1.0000e-04
# Epoch 5/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8565 - loss: 0.4179
# Epoch 5: val_accuracy did not improve from 0.42023
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.8605 - loss: 0.4201 - val_accuracy: 0.4018 - val_loss: 1.4133 - learning_rate: 1.0000e-04
# Epoch 6/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8688 - loss: 0.3997
# Epoch 6: val_accuracy improved from 0.42023 to 0.78502, saving model to cnn_model.keras
#
# Epoch 6: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.8683 - loss: 0.3988 - val_accuracy: 0.7850 - val_loss: 0.6015 - learning_rate: 1.0000e-04
# Epoch 7/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8764 - loss: 0.3958
# Epoch 7: val_accuracy did not improve from 0.78502
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.8710 - loss: 0.3990 - val_accuracy: 0.5253 - val_loss: 1.1957 - learning_rate: 1.0000e-04
# Epoch 8/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8849 - loss: 0.3881
# Epoch 8: val_accuracy improved from 0.78502 to 0.92121, saving model to cnn_model.keras
#
# Epoch 8: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.8858 - loss: 0.3801 - val_accuracy: 0.9212 - val_loss: 0.3825 - learning_rate: 1.0000e-04
# Epoch 9/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8908 - loss: 0.3667
# Epoch 9: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.8916 - loss: 0.3688 - val_accuracy: 0.7412 - val_loss: 0.6919 - learning_rate: 1.0000e-04
# Epoch 10/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8961 - loss: 0.3537
# Epoch 10: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.9016 - loss: 0.3485 - val_accuracy: 0.8541 - val_loss: 0.4811 - learning_rate: 1.0000e-04
# Epoch 11/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8925 - loss: 0.3592
# Epoch 11: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.8992 - loss: 0.3528 - val_accuracy: 0.3239 - val_loss: 3.1847 - learning_rate: 1.0000e-04
# Epoch 12/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9038 - loss: 0.3370
# Epoch 12: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9057 - loss: 0.3458 - val_accuracy: 0.4864 - val_loss: 1.5381 - learning_rate: 1.0000e-04
# Epoch 13/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9064 - loss: 0.3376
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 13: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - accuracy: 0.9048 - loss: 0.3407 - val_accuracy: 0.8521 - val_loss: 0.4782 - learning_rate: 1.0000e-04
# Epoch 14/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9149 - loss: 0.3166
# Epoch 14: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.9198 - loss: 0.3266 - val_accuracy: 0.8628 - val_loss: 0.4851 - learning_rate: 5.0000e-05
# Epoch 15/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9190 - loss: 0.3285
# Epoch 15: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9232 - loss: 0.3199 - val_accuracy: 0.7101 - val_loss: 0.7616 - learning_rate: 5.0000e-05
# Epoch 16/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9165 - loss: 0.3168
# Epoch 16: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9203 - loss: 0.3187 - val_accuracy: 0.4971 - val_loss: 1.3147 - learning_rate: 5.0000e-05
# Epoch 17/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9282 - loss: 0.3100
# Epoch 17: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9293 - loss: 0.3099 - val_accuracy: 0.7588 - val_loss: 0.6644 - learning_rate: 5.0000e-05
# Epoch 18/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9188 - loss: 0.3227
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 18: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9223 - loss: 0.3163 - val_accuracy: 0.5720 - val_loss: 1.2001 - learning_rate: 5.0000e-05
# Epoch 19/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9261 - loss: 0.3165
# Epoch 19: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9295 - loss: 0.3102 - val_accuracy: 0.8872 - val_loss: 0.4182 - learning_rate: 2.5000e-05
# Epoch 20/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9242 - loss: 0.3243
# Epoch 20: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9259 - loss: 0.3034 - val_accuracy: 0.7121 - val_loss: 0.7096 - learning_rate: 2.5000e-05
# Epoch 21/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9382 - loss: 0.2971
# Epoch 21: val_accuracy did not improve from 0.92121
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9363 - loss: 0.2973 - val_accuracy: 0.7257 - val_loss: 0.6982 - learning_rate: 2.5000e-05
# Epoch 22/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9354 - loss: 0.2955
# Epoch 22: val_accuracy improved from 0.92121 to 0.95331, saving model to cnn_model.keras
#
# Epoch 22: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9354 - loss: 0.3006 - val_accuracy: 0.9533 - val_loss: 0.3006 - learning_rate: 2.5000e-05
# Epoch 23/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9318 - loss: 0.2937
# Epoch 23: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9271 - loss: 0.3025 - val_accuracy: 0.9426 - val_loss: 0.3277 - learning_rate: 2.5000e-05
# Epoch 24/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9299 - loss: 0.2902
# Epoch 24: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9327 - loss: 0.3011 - val_accuracy: 0.8142 - val_loss: 0.5652 - learning_rate: 2.5000e-05
# Epoch 25/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9334 - loss: 0.2927
# Epoch 25: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9329 - loss: 0.2940 - val_accuracy: 0.9416 - val_loss: 0.3095 - learning_rate: 2.5000e-05
# Epoch 26/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9353 - loss: 0.2942
# Epoch 26: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.9339 - loss: 0.2934 - val_accuracy: 0.9251 - val_loss: 0.3457 - learning_rate: 2.5000e-05
# Epoch 27/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9366 - loss: 0.2931
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 27: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9380 - loss: 0.2878 - val_accuracy: 0.9037 - val_loss: 0.3787 - learning_rate: 2.5000e-05
# Epoch 28/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9331 - loss: 0.2929
# Epoch 28: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9351 - loss: 0.2898 - val_accuracy: 0.9436 - val_loss: 0.3001 - learning_rate: 1.2500e-05
# Epoch 29/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9406 - loss: 0.2801
# Epoch 29: val_accuracy did not improve from 0.95331
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9424 - loss: 0.2862 - val_accuracy: 0.8541 - val_loss: 0.4599 - learning_rate: 1.2500e-05
# Epoch 30/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9347 - loss: 0.2884
# Epoch 30: val_accuracy improved from 0.95331 to 0.95428, saving model to cnn_model.keras
#
# Epoch 30: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9400 - loss: 0.2913 - val_accuracy: 0.9543 - val_loss: 0.2868 - learning_rate: 1.2500e-05
# Epoch 31/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9464 - loss: 0.2758
# Epoch 31: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9427 - loss: 0.2809 - val_accuracy: 0.8541 - val_loss: 0.4866 - learning_rate: 1.2500e-05
# Epoch 32/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9473 - loss: 0.2926
# Epoch 32: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9414 - loss: 0.2889 - val_accuracy: 0.9504 - val_loss: 0.2951 - learning_rate: 1.2500e-05
# Epoch 33/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9476 - loss: 0.2725
# Epoch 33: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9480 - loss: 0.2828 - val_accuracy: 0.9523 - val_loss: 0.3009 - learning_rate: 1.2500e-05
# Epoch 34/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9416 - loss: 0.2853
# Epoch 34: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9470 - loss: 0.2822 - val_accuracy: 0.9475 - val_loss: 0.2900 - learning_rate: 1.2500e-05
# Epoch 35/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9440 - loss: 0.2819
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 35: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9453 - loss: 0.2815 - val_accuracy: 0.9484 - val_loss: 0.2980 - learning_rate: 1.2500e-05
# Epoch 36/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9389 - loss: 0.2923
# Epoch 36: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9429 - loss: 0.2841 - val_accuracy: 0.9416 - val_loss: 0.3191 - learning_rate: 6.2500e-06
# Epoch 37/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9424 - loss: 0.2844
# Epoch 37: val_accuracy did not improve from 0.95428
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9378 - loss: 0.2815 - val_accuracy: 0.9514 - val_loss: 0.2919 - learning_rate: 6.2500e-06
# Epoch 38/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9434 - loss: 0.2711
# Epoch 38: val_accuracy improved from 0.95428 to 0.95525, saving model to cnn_model.keras
#
# Epoch 38: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9446 - loss: 0.2793 - val_accuracy: 0.9553 - val_loss: 0.2935 - learning_rate: 6.2500e-06
# Epoch 39/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9382 - loss: 0.2839
# Epoch 39: val_accuracy did not improve from 0.95525
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9427 - loss: 0.2836 - val_accuracy: 0.9484 - val_loss: 0.2843 - learning_rate: 6.2500e-06
# Epoch 40/40
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9423 - loss: 0.2832
# Epoch 40: val_accuracy improved from 0.95525 to 0.95623, saving model to cnn_model.keras
#
# Epoch 40: finished saving model to cnn_model.keras
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9431 - loss: 0.2798 - val_accuracy: 0.9562 - val_loss: 0.2826 - learning_rate: 6.2500e-06

# %%
# ---------------- EVALUATION ----------------
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_acc:.4f}")

y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=CLASS_NAMES))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_true, y_pred_classes))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.8245 - loss: 0.5742
#
# Test Accuracy: 0.8245
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 436ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      COVID19       0.95      0.98      0.97       116
#       NORMAL       0.59      0.97      0.73       317
#    PNEUMONIA       0.99      0.75      0.85       855
#
#     accuracy                           0.82      1288
#    macro avg       0.84      0.90      0.85      1288
# weighted avg       0.89      0.82      0.83      1288
#
#
# Confusion Matrix:
#
# [[114   2   0]
#  [  4 306   7]
#  [  2 211 642]]

# %%
# ---------------- GRAD-CAM ----------------
def get_gradcam(model, img_array, class_index, layer_name=None):
    if layer_name is None:
        # choose last conv layer
        for layer in reversed(model.layers):
            if isinstance(layer, tf.keras.layers.Conv2D):
                layer_name = layer.name
                break

    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, class_index]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# Example Grad-CAM usage
import cv2

sample_img_path = test_generator.filepaths[0]
img = tf.keras.preprocessing.image.load_img(sample_img_path, target_size=IMG_SIZE)
img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

pred_class = np.argmax(model.predict(img_array))
heatmap = get_gradcam(model, img_array, pred_class)

# Overlay heatmap
img_orig = cv2.imread(sample_img_path)
img_orig = cv2.resize(img_orig, IMG_SIZE)
heatmap = cv2.resize(heatmap, (IMG_SIZE[1], IMG_SIZE[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(img_orig, 0.6, heatmap, 0.4, 0)
cv2.imwrite("gradcam_example.jpg", superimposed_img)
print("Grad-CAM saved to gradcam_example.jpg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 26
#      23     return heatmap.numpy()
#      25 # Example Grad-CAM usage
# ---> 26 import cv2
#      28 sample_img_path = test_generator.filepaths[0]
#      29 img = tf.keras.preprocessing.image.load_img(sample_img_path, target_size=IMG_SIZE)
#
# ModuleNotFoundError: No module named 'cv2'
